# %%
# Ran pip install -ipython sql in Terminal

# %%
# load the sql extension 
# %load_ext sql

# %%
# Installed psycopg2 in Terminal to connect to Postgres Database

# %%
#Connect to database 
# %sql postgresql://postgres:kings@localhost:5432/Gun_Violence

# %%
# %%sql
#
# SELECT * FROM gun_violence
# LIMIT 5;
# Out:
#  * postgresql://postgres:***@localhost:5432/Gun_Violence
# 5 rows affected.
# [(0, 'Orange office complex shooting', 'Orange, California', '3/31/21', 'Aminadab Gaxiola Gonzalez, 44, allegedly opened fire inside a small business at an office complex, killing at least four victims, including a nine-ye ... (91 characters truncated) ... ording to law enforcement officials, Gonzalez had chained the front and rear gates to the complex with bicycle cable locks to hinder police response.', 4, 1, 5, 'Workplace', '-', '-', '-', '-', '-', 'semiautomatic handgun', '-', '-', 'M', 'https://www.latimes.com/california/story/2021-03-31/orange-mass-shooting-reported; https://www.ocregister.com/2021/03/31/orange-shooting-draws-large- ... (20 characters truncated) ... iple-victims-found/; https://www.sandiegouniontribune.com/news/california/story/2021-04-01/police-california-office-attack-that-killed-4-wasnt-random', '-', '-', 33.83542, -117.85379, 'Mass', 2021),
# ...
