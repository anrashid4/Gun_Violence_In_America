# %%
# Import Pandas
import pandas as pd

# %%
# Create dataframe with file path

df = pd.read_csv('Mass Shootings.csv')

# %%
#Display first 5 rows to ensure file path was correct 

df.head()
# Out:
#                                      case               location     date  \
# 0          Orange office complex shooting     Orange, California  3/31/21
# 1            Boulder supermarket shooting      Boulder, Colorado  3/22/21
# 2        Atlanta massage parlor shootings       Atlanta, Georgia  3/16/21
# 3  Springfield convenience store shooting  Springfield, Missouri  3/16/20
# 4                   Molson Coors shooting   Milwaukee, Wisconsin  2/26/20
#
#                                              summary  fatalities  injured  \
# 0  Aminadab Gaxiola Gonzalez, 44, allegedly opene...           4        1
# 1  Ahmad Al Aliwi Alissa, 21, carried out a mass ...          10        0
# 2  Robert Aaron Long, 21, killed eight people at ...           8        1
# 3  Joaquin S. Roman, 31, went on a rampage culmin...           4        0
# 4  Anthony Ferrill, 51, an employee armed with tw...           5        0
#
#    total_victims location.1 age_of_shooter prior_signs_mental_health_issues  \
# 0              5  Workplace              -                                -
# 1             10  Workplace             21                              yes
# 2              9  Workplace             21                                -
# 3              4  Workplace             31                                -
# 4              5  Workplace             51                                -
#
#    ...                                     weapon_details   race gender  \
# 0  ...                                                  -      -      M
# 1  ...  Ruger AR-556; weapon was purchased six days be...      -      M
# 2  ...                                                  -  White      M
# 3  ...                                                  -      -      M
# 4  ...                                                  -  Black      M
#
#                                              sources  \
# 0  https://www.latimes.com/california/story/2021-...
# 1  https://www.denverpost.com/2021/03/22/police-a...
# 2  https://www.ajc.com/news/breaking-multiple-sho...
# 3  https://www.kiro7.com/news/trending/ive-been-s...
# 4  https://www.jsonline.com/story/news/local/2020...
#
#                                mental_health_sources sources_additional_age  \
# 0                                                  -                      -
# 1  https://www.thedailybeast.com/boulder-colorado...                      -
# 2                                                  -                      -
# 3                                                  -                      -
# 4                                                  -                      -
#
#     latitude   longitude   type  year
# 0  33.835420 -117.853790   Mass  2021
# 1  39.986961 -105.251168   Mass  2021
# 2  34.111653  -84.580376  Spree  2021
# 3  37.210432  -93.236860   Mass  2020
# 4  43.044511  -87.962537   Mass  2020
#
# [5 rows x 24 columns]

# %%
#Address columns for sql 

df_columns = [c.lower() for c in df.columns]

# %%
#Import sqlalchemy and establish connection 

from sqlalchemy import create_engine
engine = create_engine('postgresql://postgres:kings@localhost:5432/Gun_Violence')

# %%
df.to_sql("gun violence", engine)
