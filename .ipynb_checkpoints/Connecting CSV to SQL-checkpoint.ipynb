# %%
# Import Pandas
import pandas as pd

# %%
# Create dataframe with file path

df = pd.read_csv('Original.csv')

# %%
#Display rows to ensure file path was correct 

df
# Out:
#                                        case                location  \
# 0                  FedEx warehouse shooting   Indianapolis, Indiana
# 1            Orange office complex shooting      Orange, California
# 2              Boulder supermarket shooting       Boulder, Colorado
# 3          Atlanta massage parlor shootings        Atlanta, Georgia
# 4    Springfield convenience store shooting   Springfield, Missouri
# ..                                      ...                     ...
# 118         Shopping centers spree killings       Palm Bay, Florida
# 119   United States Postal Service shooting        Edmond, Oklahoma
# 120          San Ysidro McDonald's massacre  San Ysidro, California
# 121               Dallas nightclub shooting           Dallas, Texas
# 122                   Welding shop shooting          Miami, Florida
#
#           date                                            summary  fatalities  \
# ...

# %%
df["sources"].value_counts
# Out:
# <bound method IndexOpsMixin.value_counts of 0      https://www.indystar.com/story/news/crime/2021...
# 1      https://www.latimes.com/california/story/2021-...
# 2      https://www.denverpost.com/2021/03/22/police-a...
# 3      https://www.ajc.com/news/breaking-multiple-sho...
# 4      https://www.kiro7.com/news/trending/ive-been-s...
#                              ...
# 118    http://articles.latimes.com/1987-04-25/news/mn...
# 119    http://news.google.com/newspapers?id=dm8aAAAAI...
# 120    http://www.utsandiego.com/san-ysidro-massacre/...
# 121    http://books.google.com/books?id=Hr3OBwP-lbUC&...
# 122    http://www.nytimes.com/1982/08/21/us/gunman-in...
# Name: sources, Length: 123, dtype: object>

# %%
#Address columns for sql 

df_columns = [c.lower() for c in df.columns]

# %%
#Import sqlalchemy and establish connection 

from sqlalchemy import create_engine
engine = create_engine('postgresql://postgres:49ers@localhost:5432/Gun_Violence')

# %%
#Take dataframe to PostgreSQL
df.to_sql("gun violence", engine)
